# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score, f1_score, precision_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score, roc_curve

# %%
my_work = pd.read_csv('studentadmission.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 my_work = pd.read_csv('studentadmission.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
my_work.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 my_work.info()
#
# NameError: name 'my_work' is not defined

# %%
my_work.head(99)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 my_work.head(99)
#
# NameError: name 'my_work' is not defined

# %%
my_work.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 my_work.tail()
#
# NameError: name 'my_work' is not defined

# %%
my_work.isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 my_work.isnull()
#
# NameError: name 'my_work' is not defined

# %%
my_work.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 my_work.isnull().sum()
#
# NameError: name 'my_work' is not defined

# %%
my_work.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 my_work.duplicated().sum()
#
# NameError: name 'my_work' is not defined

# %%
num_duplicated = my_work.duplicated()
print("num of dulpicate" ,num_duplicated)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 num_duplicated = my_work.duplicated()
#       2 print("num of dulpicate" ,num_duplicated)
#
# NameError: name 'my_work' is not defined

# %%
plt.figure(figsize=(10,8))
sns.boxplot(my_work)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 plt.figure(figsize=(10,8))
# ----> 2 sns.boxplot(my_work)
#
# NameError: name 'my_work' is not defined

# %%
plt.figure(figsize=(8,4))
sns.heatmap(my_work.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 plt.figure(figsize=(8,4))
# ----> 2 sns.heatmap(my_work.corr(),annot=True)
#
# NameError: name 'my_work' is not defined

# %%
plt.figure(figsize=(8,4))
sns.heatmap(my_work.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 plt.figure(figsize=(8,4))
# ----> 2 sns.heatmap(my_work.corr(),annot=True)
#
# NameError: name 'my_work' is not defined

# %%
x = my_work[['Score1', 'Score2']]
y = my_work['Admission']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 x = my_work[['Score1', 'Score2']]
#       2 y = my_work['Admission']
#
# NameError: name 'my_work' is not defined

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)
#
# NameError: name 'x' is not defined

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 scaler = StandardScaler()
# ----> 2 x_train_scaled = scaler.fit_transform(x_train)
#       3 x_test_scaled = scaler.transform(x_test)
#
# NameError: name 'x_train' is not defined
